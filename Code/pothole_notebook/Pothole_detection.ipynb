# %% [markdown]
# #**Monter google drive**

# %%
from google.colab import drive

drive.mount('Pour des raisons de confidentialité et de sécurité, je restreins l\'accès à mon compte google drive. Veuillez me contacter si nécessaire.')

# %% [markdown]
# #**Installer les librairies**

# %%
pip install ultralytics opencv-python

# %% [markdown]
# #**Importer les librairie**

# %%
from IPython.display import Image
import torch
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# #**Importer le dataset**

# %%
from os.path import exists
DATA_YAMAL_PATH = "Chemin vers le fichier data.yaml"

# vérification

if not exists(DATA_YAMAL_PATH) :
  print("Ce fichier n'existe pas")
  print(DATA_YAMAL_PATH)
else:
  print("Data set trouvé")
# Out:
# Data set trouvé

# %% [markdown]
# #**Charger le modèle et lancer l'entrainement**

# %%
model = YOLO('yolov8n.pt')

results = model.train(data = DATA_YAMAL_PATH, epochs = 100)
# Out:
# ...
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# #**Tester le modèle**

# %%
# !zip -r /content/model_weights.zip /content/runs/detect/train/weights

from google.colab import files

files.download('/content/model_weights.zip')
# Out:
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
